# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Yethishwar " * 10)
# Out:
# Yethishwar Yethishwar Yethishwar Yethishwar Yethishwar Yethishwar Yethishwar Yethishwar Yethishwar Yethishwar

# %%
patient_name = "Yethish"
age = 20
patient_type = "new"

# %%
name = input("Enter your name?")
color = input("Your Favourite color?")
print(f"{name} likes {color} color")
# Out:
# Enter your name? yethish
# Your Favourite color? red
# yethish likes red color

# %%
weight = int(input("Enter weight in pounds")) # one pound = 0.45 kilogram
# 1 = 0.45
# 2 = 0.45 * 2
# 3 = o.45 * 3
kilograms = weight * 0.453
print(round(kilograms,2))
# Out:
# Enter weight in pounds 3
# 1.36

# %%
# For multi line strig we use ''' ---- '''

# %%
mystring = "Yethishwar"
mystring[-1: -5:-1]
# Out:
# 'rawh'

# %%
mystring.find('o') # find returns -1 if substring doesn't exists
# Out:
# -1

# %%
mystring.index('Y') # index retirn value error and also it is applicablel for all sequesntial data type in python
# Out:
# 0

# %%
# Out:
# 2

# %%
print(abs(-120))
# Out:
# 120

# %%
import math
print(round(2.5))
# Out:
# 2

# %%
day_type = input("How was the day dude?")
day_type day_type.lower().strip()
if day_type == "hot":
    print("Drink plenty of water")
elif day_type == "cold":
    print("Wear Worm cloths")
else:
    print("It's a lovely day")

# %%
temp = 20
if temp > 30:
    print("Hot day")
elif temp < 10:
    print("Cold Day")
else:
    pass
